# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelgupta13/ML/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
arr=np.array([(1,2),(2,3),(3,2),(4,4),(8,8),(7,9),(4,5),(7,13),(4,16),(8,7),(2,9)])

# %%
plt.scatter(arr[:,0],arr[:,1])
plt.show()

# %%
db=DBSCAN(eps=3,min_samples=2)
db.fit(arr)
db.labels_
# Out:
# array([ 0,  0,  0,  0,  1,  1,  0, -1, -1,  1, -1])

# %% [markdown]
# now working on concentric circle dataset

# %%
from sklearn.datasets import make_circles
from sklearn.cluster import DBSCAN

# %%
X,_=make_circles(n_samples=500, factor=.5,noise=.03,random_state=4)
dbscan=DBSCAN(eps=0.2,min_samples=5)
clusters=dbscan.fit_predict(X)

plt.scatter(X[:,0],X[:,1],c=clusters,cmap='viridis',marker='o')
plt.title('concentric circle dataset')
plt.xlabel("feature 0")
plt.ylabel("feature 1")
plt.show()
