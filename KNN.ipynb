# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelgupta13/ML/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('Mall_Customers.csv')

# %%
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
dataset.shape
# Out:
# (200, 5)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(dataset.iloc[:,2:4],dataset.iloc[:,4],test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#      Age  Annual Income (k$)
# 137   32                  73
# 163   31                  81
# 111   19                  63
# 123   39                  69
# 109   66                  63

# %%
X_train.shape
# Out:
# (160, 2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.49891353,  0.42931283],
#        [-0.57194754,  0.7471384 ],
#        [-1.44835558,  0.03203086],
#        [ 0.01232449,  0.27040004],
#        [ 1.98424258,  0.03203086],
#        [-0.49891353,  0.50876922],
#        [-1.08318556, -0.96117406],
#        [ 0.59659651,  0.34985643],
#        [ 1.32693655,  0.50876922],
#        [-1.22925357, -1.7954662 ],
#        [-0.64498154,  0.62795381],
#        [-1.15621956, -0.00769734],
#        [-0.27981152, -1.71600981],
#        [-0.79104955,  1.54170234],
#        [ 1.10783454, -1.35845603],
#        [ 0.81569852, -0.16661013],
#        [ 0.3044605 , -0.5638921 ],
#        [ 1.83817457, -1.71600981],
#        [-0.20677752,  0.98550759],
#        [-0.64498154,  1.02523578],
#        [ 0.08535849, -1.31872784],
#        [-0.57194754,  0.38958463],
#        [-0.49891353, -0.08715373],
#        [ 0.66963052, -0.92144587],
#        [-0.49891353,  0.98550759],
#        [ 2.05727658, -0.32552291],
#        [ 0.15839249,  1.46224595],
# ...

# %%
X_train.shape
# Out:
# (160, 2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
from sklearn.metrics import accuracy_score
y_pred=knn.predict(X_test)
accuracy_score(y_test,y_pred)

# %%
score=[]
for i in range (1,15):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    y_pred=knn.predict(X_test)
    score.append(accuracy_score(y_test,y_pred))
plt.plot(range(1,15),score)
